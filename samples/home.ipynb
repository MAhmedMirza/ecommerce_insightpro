# %%
# !pip install flask

# %%
from flask import Flask, render_template_string
import threading
import webbrowser

# Initialize Flask app
app = Flask(__name__)

# Route for home page
@app.route('/')
def home():
    return render_template_string("""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>E-Commerce InsightPro</title>
    <link rel="stylesheet" href="/static/home.css">
</head>

<body>
    <header>
        <div class="container">
            <div class="header-content">
                <h1>E-Commerce <span>InsightPro</span></h1>
                <p>Transform Your E-Commerce Success with Actionable Insights Revolutionizing Marketing Strategies for Unparalleled Growth!</p>
                <button class="circular-button" onclick="location.href='#section4'">Learn More</button>
            </div>
            <div class="header-image-placeholder">
                <div class="header-image">
                    <img src="/static/img/1.png" alt="Img1">
                </div>
            </div>
        </div>
    </header>

    <main>
        <section class="section1">
            <div class="container">
                <div class="section1-content">
                    <div class="goal">
                        <div class="image-container"> 
                            <img src="/static/img/dashboard_Blog.jpg" alt="Goal 1">
                        </div>
                        <div class="goal-content">
                            <h2>The <span class="highlight">goals</span> we know you're trying to achieve</h2>
                            <p>A web-based platform that uses ETL pipelines to clean and organize data for RFM analysis.
                            This will segment customers into groups like loyal or at-risk, with insights visualized through interactive dashboards.</p>
                            <p><b>The platform will help e-commerce businesses improve customer engagement, retention, and sales through data-driven decisions.</b></p>
                        </div>
                    </div>
                </div>
            </div>
        </section>

        <section class="section2">
            <div class="container">
                <h2>Our solutions in more detail</h2>
                <div class="solutions">
                    <div class="solution">
                        <div class="image-wrapper">
                            <img src="/static/img/download.jpeg" alt="Solution 1" width="300px" height="200px">
                        </div>
                        <h3>ETL</h3>
                        <p>ETL pipelines to clean, structure, and centralize data for accurate RFM analysis and customer segmentation.</p>
                    </div>
                    <div class="solution">
                        <div class="image-wrapper">
                            <img src="/static/img/0_jObcs9FvVBTRAy58.png" alt="Solution 2" width="300px" height="200px">
                        </div>
                        <h3>RFM</h3>
                        <p>RFM analysis to make customers segments based on their recency, frequency, and monetary behaviors to provide actionable insights.</p>
                    </div>
                    <div class="solution">
                        <div class="image-wrapper">
                            <img src="/static/img/images.jpeg" alt="Solution 3" width="300px" height="200px">
                        </div>
                        <h3>Dashboard</h3>
                        <p>The dashboard will visualizes customer segments and RFM insights for data-driven decision-making.</p>
                    </div>
                </div>
            </div>
        </section>

        <section class="section3">
            <div class="container">
                <div class="signup-login">
                    <div class="left-content">
                        <h2>Sign Up or Log In <br> to Unlock Powerful <br> Customer Insights</h2>
                    </div>
                    <div class="right-content" id="section4">
                        <p>Sign up or log in to our platform to unlock powerful, personalized customer insights through cutting-edge RFM analysis. 
                        Dive deeper into your customers' behaviors, tailor your strategies with precision, and achieve extraordinary engagement 
                        and loyalty. Maximize your e-commerce performance with data-driven decisions that boost growth, elevate customer experiences,
                        and set you apart in today’s competitive market – all seamlessly integrated in one user-friendly platform!</p>
                    </div>
                    <div class="buttons">
                        <button class="circular-button">Sign Up</button>
                        <button class="circular-button">Log In</button>
                    </div>
                </div>
            </div>
        </section>
    </main>

    <footer>
        <div class="container">
            <div class="footer-content">
                <div class="left-content">
                    <h2>E-Commerce <span class="highlight">InsightPro</span></h2>
                    <div class="contact-details">
                        <h3>Contact Us:</h3>
                        <h4><strong>ADDRESS</strong><p>Lahore, Pakistan</p></h4>
                        <h4><strong>PHONE</strong><p>03019113476</p></h4>
                        <h4><strong>EMAIL</strong><p>studiomagic544@gmail.com</p></h4>
                    </div>
                </div>
                <div class="right-content">
                    <img src="/static/img/2.png" alt="Footer Image">
                </div>
            </div>
            <div class="footer-bottom">
                <hr> 
                <div class="bottom-text">
                    <p>&copy; Copyright 2024 Ecommerce InsightPro</p>
                    <p>Privacy Policy</p>
                    <p>Term and Conditions</p>
                </div>
            </div>
        </div>
    </footer>
</body>
</html>
""")

# Function to run the Flask app
def run_app():
    app.run(debug=False, port=5000)

# Start Flask in a new thread so it doesn't block the notebook
threading.Thread(target=run_app).start()

# Automatically open in browser
webbrowser.open("http://127.0.0.1:5000/")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# True
# 127.0.0.1 - - [10/Apr/2025 11:49:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:30] "GET /static/home.css HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:30] "GET /static/img/dashboard_Blog.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:30] "GET /static/img/images.jpeg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:30] "GET /static/img/1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:30] "GET /static/img/0_jObcs9FvVBTRAy58.png HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:30] "GET /static/img/download.jpeg HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:30] "GET /static/img/2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Apr/2025 11:49:31] "GET /favicon.ico HTTP/1.1" 404 -
# ...
